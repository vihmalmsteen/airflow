# %%
import os
from airflow import DAG
from airflow.operators.bash import BashOperator
from airflow.operators.python import PythonOperator
import sqlalchemy
import pandas as pd
# Out:
# c:\Users\vitor\Desktop\airflow\.venv\Lib\site-packages\airflow\__init__.py:45: RuntimeWarning: Airflow currently can be run on POSIX-compliant Operating Systems. For development, it is regularly tested on fairly modern Linux Distros and recent versions of macOS. On Windows you can run it via WSL2 (Windows Subsystem for Linux 2) or via Linux Containers. The work to add Windows support is tracked via https://github.com/apache/airflow/issues/10388, but it is not a high priority.
#   warnings.warn(
# 2026-02-21T17:42:54.689215Z [info     ] setup plugin alembic.autogenerate.schemas [alembic.runtime.plugins] loc=plugins.py:37
# 2026-02-21T17:42:54.692215Z [info     ] setup plugin alembic.autogenerate.tables [alembic.runtime.plugins] loc=plugins.py:37
# 2026-02-21T17:42:54.695214Z [info     ] setup plugin alembic.autogenerate.types [alembic.runtime.plugins] loc=plugins.py:37
# 2026-02-21T17:42:54.698746Z [info     ] setup plugin alembic.autogenerate.constraints [alembic.runtime.plugins] loc=plugins.py:37
# 2026-02-21T17:42:54.702524Z [info     ] setup plugin alembic.autogenerate.defaults [alembic.runtime.plugins] loc=plugins.py:37
# 2026-02-21T17:42:54.705523Z [info     ] setup plugin alembic.autogenerate.comments [alembic.runtime.plugins] loc=plugins.py:37
# C:\Users\vitor\AppData\Local\Temp\ipykernel_26424\881033566.py:3 DeprecatedImportWarning: The `airflow.operators.bash.BashOperator` attribute is deprecated. Please use `'airflow.providers.standard.operators.bash.BashOperator'`.
# C:\Users\vitor\AppData\Local\Temp\ipykernel_26424\881033566.py:4 DeprecatedImportWarning: The `airflow.operators.python.PythonOperator` attribute is deprecated. Please use `'airflow.providers.standard.operators.python.PythonOperator'`.

# %%
DATABASE_URL = "sqlite:///database/database.sql"
engine = sqlalchemy.create_engine(DATABASE_URL)

with engine.connect() as _conn:
    df = pd.DataFrame(
        _conn.execute(sqlalchemy.text('''
        SELECT name FROM sqlite_schema
        WHERE type='table' AND name NOT LIKE 'sqlite_%'
        ORDER BY name;
        '''))
    )
df
# Out:
#            name
# 0  itens_pedido
# 1       pedidos
# 2      produtos
# 3      usuarios
